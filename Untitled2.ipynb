# %%
Name=str(input("enter the name:"))
Age=int(input("enter the age"))

if Age>18:
  print("you are eligible for voting")
else:
  print("you are Not eligible For voting")
# Out:
# enter the name:Mohamed safic rahman
# enter the age20
# you are eligible for voting
