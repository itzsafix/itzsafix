# %%
d= lambda c,b:c+b
d(90,89)
# Out:
# 179

# %%
l1=[1,2,3,4,5,6]
l1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
w=lambda n*n(l1)
w
# Out:
#   File "<ipython-input-6-1eb2786725cc>", line 1
#     w=lambda n*n(l1)
#               ^
# SyntaxError: invalid syntax

# %%
open('C:\Users\safic\OneDrive\Desktop')
# Out:
#   File "<ipython-input-8-b4b423479e02>", line 1
#     open('C:\Users\safic\OneDrive\Desktop')
#                                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
f=open('C:\Users\safic\OneDrive\Desktop')
f
# Out:
#   File "<ipython-input-9-79df25c871c1>", line 1
#     f=open('C:\Users\safic\OneDrive\Desktop')
#                                             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
