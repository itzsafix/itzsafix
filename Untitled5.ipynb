# %%
a=str(input("enter the name"))
b=int(input("enter the marks"))

if b>90 and b<100:
  print("excellent")
elif b>80 and b<89:
  print("very good")
elif b>60 and b<79:
  print("good")
elif b>45 and b<59:
  print("average")
else:
  print("worst")
# Out:
# enter the nameFarun
# enter the marks65
# good

# %%
a=float(input("enter the neet percentage"))
if neet %>

if a>185.8:
  print("you are eligible For doctor sheet")
else:
  print("not eligible for doctor sheet")
# Out:
# enter the neet percentage175.0
# not eligible for doctor sheet

# %%
if v>456:
  v=int(input('entert the 10th marks'))

if c>556:
  c=int(input("enter the 12th marks:"))
  print("you are scored higher marks both 10th and 12th,you are eligible for medical college")
# Out:
# enter the 12th marks:567
# you are scored higher marks both 10th and 12th,you are eligible for medical college
