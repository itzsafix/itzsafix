# %% [markdown]
# Basics of python

# %%
56>=67
# Out:
# False

# %%
a="safic rahman"
a
# Out:
# 'safic rahman'

# %%
a="""you can now embed Google sheets directly into Colab to streamline interactions with data with interactive sheet
Example:
from google.colab import sheets
sh=sheets. Interactivesheet()
df=sh.as_()"""
print(a)
# Out:
# you can now embed Google sheets directly into Colab to streamline interactions with data with interactive sheet
# Example:
# from google.colab import sheets
# sh=sheets. Interactivesheet()
# df=sh.as_()

# %%
a="guvi"+"2"
a
# Out:
# 'guvi2'
